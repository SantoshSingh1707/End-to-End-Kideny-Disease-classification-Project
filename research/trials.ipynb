# %% [markdown]
# ## Download data from gdrive

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id) , "Chest-CT-scan-data.zip"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3&confirm=t&uuid=73ccfa48-fde5-4a42-a698-ff779e365d9d
# To: c:\Users\Santosh\Desktop\ML-Project-Deployment\MLOPS\End-to-End-Deep-Learning-Project\End-to-End-Kideny-Disease-classification-Project\research\kidney-ct-scan-image.zip
# 100%|██████████| 57.7M/57.7M [00:11<00:00, 5.17MB/s]
# ('kidney-ct-scan-image.zip', 'Chest-CT-scan-data.zip')
